# %%
pip install https://github.com/kartograph/kartograph.py/zipball/master -r https://raw.github.com/kartograph/kartograph.py/master/requirements.txt
# Out:
# -------
# WARNING: Discarding https://files.pythonhosted.org/packages/e6/b5/346cbd96837f5ed525d0460090d24e8cfb31ad805c6d5297ee4998eb81b6/GDAL-1.10.0.tar.gz#sha256=1f95b3219616387f3da23c18bea030fa46b4b581091de3aa7c32466d62aade4c (from https://pypi.org/simple/gdal/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading GDAL-1.9.1.tar.gz (420 kB)
#      |████████████████████████████████| 420 kB 1.4 MB/s
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-xw3wmjeh/gdal_c98e62b846b94f3fa300e73cdd3463aa/setup.py'"'"'; __file__='"'"'/tmp/pip-install-xw3wmjeh/gdal_c98e62b846b94f3fa300e73cdd3463aa/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-zygv4hg4
#          cwd: /tmp/pip-install-xw3wmjeh/gdal_c98e62b846b94f3fa300e73cdd3463aa/
#     Complete output (52 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-zygv4hg4/GDAL.egg-info
#     writing /tmp/pip-pip-egg-info-zygv4hg4/GDAL.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-zygv4hg4/GDAL.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-zygv4hg4/GDAL.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-zygv4hg4/GDAL.egg-info/SOURCES.txt'
#     Traceback (most recent call last):
#       File "/tmp/pip-install-xw3wmjeh/gdal_c98e62b846b94f3fa300e73cdd3463aa/setup.py", line 89, in fetch_config
#         p = subprocess.Popen([command, args], stdout=subprocess.PIPE)
#       File "/usr/lib/python3.8/subprocess.py", line 854, in __init__
#         self._execute_child(args, executable, preexec_fn, close_fds,
#       File "/usr/lib/python3.8/subprocess.py", line 1702, in _execute_child
#         raise child_exception_type(errno_num, err_msg, err_filename)
#     FileNotFoundError: [Errno 2] No such file or directory: '../../apps/gdal-config'
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-xw3wmjeh/gdal_c98e62b846b94f3fa300e73cdd3463aa/setup.py", line 250, in <module>
#         setup( name = name,
#       File "/home/alex/.local/lib/python3.8/site-packages/setuptools/__init__.py", line 153, in setup
#         return distutils.core.setup(**attrs)
#       File "/usr/lib/python3.8/distutils/core.py", line 148, in setup
#         dist.run_commands()
#       File "/usr/lib/python3.8/distutils/dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "/usr/lib/python3.8/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/home/alex/.local/lib/python3.8/site-packages/setuptools/command/egg_info.py", line 299, in run
#         self.find_sources()
#       File "/home/alex/.local/lib/python3.8/site-packages/setuptools/command/egg_info.py", line 306, in find_sources
#         mm.run()
#       File "/home/alex/.local/lib/python3.8/site-packages/setuptools/command/egg_info.py", line 541, in run
#         self.add_defaults()
#       File "/home/alex/.local/lib/python3.8/site-packages/setuptools/command/egg_info.py", line 577, in add_defaults
#         sdist.add_defaults(self)
#       File "/usr/lib/python3.8/distutils/command/sdist.py", line 228, in add_defaults
#         self._add_defaults_ext()
#       File "/usr/lib/python3.8/distutils/command/sdist.py", line 311, in _add_defaults_ext
#         build_ext = self.get_finalized_command('build_ext')
#       File "/usr/lib/python3.8/distutils/cmd.py", line 299, in get_finalized_command
#         cmd_obj.ensure_finalized()
#       File "/usr/lib/python3.8/distutils/cmd.py", line 107, in ensure_finalized
#         self.finalize_options()
#       File "/tmp/pip-install-xw3wmjeh/gdal_c98e62b846b94f3fa300e73cdd3463aa/setup.py", line 164, in finalize_options
#         self.gdaldir = self.get_gdal_config('prefix')
#       File "/tmp/pip-install-xw3wmjeh/gdal_c98e62b846b94f3fa300e73cdd3463aa/setup.py", line 135, in get_gdal_config
#         return fetch_config(option, gdal_config = self.gdal_config)
#       File "/tmp/pip-install-xw3wmjeh/gdal_c98e62b846b94f3fa300e73cdd3463aa/setup.py", line 90, in fetch_config
#         except OSError(e):
#     NameError: name 'e' is not defined
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/76/41/8b41f24fb25fd0bfd69c98444b3cab79e519c88619c0ccef8891e096dbd9/GDAL-1.9.1.tar.gz#sha256=63e44e92043f6ae55ca0ddf78d698cadb42f06ff5cb3c050b6f55edfaae8d2cc (from https://pypi.org/simple/gdal/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading GDAL-1.9.0.tar.gz (420 kB)
#      |████████████████████████████████| 420 kB 2.6 MB/s
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-xw3wmjeh/gdal_2741285b212e445ab9f2c337326e5abb/setup.py'"'"'; __file__='"'"'/tmp/pip-install-xw3wmjeh/gdal_2741285b212e445ab9f2c337326e5abb/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-txgrkdgm
#          cwd: /tmp/pip-install-xw3wmjeh/gdal_2741285b212e445ab9f2c337326e5abb/
#     Complete output (52 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-txgrkdgm/GDAL.egg-info
#     writing /tmp/pip-pip-egg-info-txgrkdgm/GDAL.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-txgrkdgm/GDAL.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-txgrkdgm/GDAL.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-txgrkdgm/GDAL.egg-info/SOURCES.txt'
#     Traceback (most recent call last):
#       File "/tmp/pip-install-xw3wmjeh/gdal_2741285b212e445ab9f2c337326e5abb/setup.py", line 89, in fetch_config
#         p = subprocess.Popen([command, args], stdout=subprocess.PIPE)
#       File "/usr/lib/python3.8/subprocess.py", line 854, in __init__
#         self._execute_child(args, executable, preexec_fn, close_fds,
#       File "/usr/lib/python3.8/subprocess.py", line 1702, in _execute_child
#         raise child_exception_type(errno_num, err_msg, err_filename)
#     FileNotFoundError: [Errno 2] No such file or directory: '../../apps/gdal-config'
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-xw3wmjeh/gdal_2741285b212e445ab9f2c337326e5abb/setup.py", line 250, in <module>
#         setup( name = name,
#       File "/home/alex/.local/lib/python3.8/site-packages/setuptools/__init__.py", line 153, in setup
#         return distutils.core.setup(**attrs)
#       File "/usr/lib/python3.8/distutils/core.py", line 148, in setup
#         dist.run_commands()
#       File "/usr/lib/python3.8/distutils/dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "/usr/lib/python3.8/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/home/alex/.local/lib/python3.8/site-packages/setuptools/command/egg_info.py", line 299, in run
#         self.find_sources()
#       File "/home/alex/.local/lib/python3.8/site-packages/setuptools/command/egg_info.py", line 306, in find_sources
#         mm.run()
#       File "/home/alex/.local/lib/python3.8/site-packages/setuptools/command/egg_info.py", line 541, in run
#         self.add_defaults()
#       File "/home/alex/.local/lib/python3.8/site-packages/setuptools/command/egg_info.py", line 577, in add_defaults
#         sdist.add_defaults(self)
#       File "/usr/lib/python3.8/distutils/command/sdist.py", line 228, in add_defaults
#         self._add_defaults_ext()
#       File "/usr/lib/python3.8/distutils/command/sdist.py", line 311, in _add_defaults_ext
#         build_ext = self.get_finalized_command('build_ext')
#       File "/usr/lib/python3.8/distutils/cmd.py", line 299, in get_finalized_command
#         cmd_obj.ensure_finalized()
#       File "/usr/lib/python3.8/distutils/cmd.py", line 107, in ensure_finalized
#         self.finalize_options()
#       File "/tmp/pip-install-xw3wmjeh/gdal_2741285b212e445ab9f2c337326e5abb/setup.py", line 164, in finalize_options
#         self.gdaldir = self.get_gdal_config('prefix')
#       File "/tmp/pip-install-xw3wmjeh/gdal_2741285b212e445ab9f2c337326e5abb/setup.py", line 135, in get_gdal_config
#         return fetch_config(option, gdal_config = self.gdal_config)
#       File "/tmp/pip-install-xw3wmjeh/gdal_2741285b212e445ab9f2c337326e5abb/setup.py", line 90, in fetch_config
#         except OSError(e):
#     NameError: name 'e' is not defined
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/4b/6e/88fdda4f2c14c2d2cb13145383d9908fb8611ff047409140845b3ba1bf3c/GDAL-1.9.0.tar.gz#sha256=bb065b46961da25e40b266d194d53d47efc0f7e23ab12984ac2f0bce99ecccc4 (from https://pypi.org/simple/gdal/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading GDAL-1.8.1.tar.gz (400 kB)
#      |████████████████████████████████| 400 kB 2.3 MB/s
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-xw3wmjeh/gdal_1a897a57203542cfb2fd55ad204ad8d1/setup.py'"'"'; __file__='"'"'/tmp/pip-install-xw3wmjeh/gdal_1a897a57203542cfb2fd55ad204ad8d1/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-we8dt0mq
#          cwd: /tmp/pip-install-xw3wmjeh/gdal_1a897a57203542cfb2fd55ad204ad8d1/
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-xw3wmjeh/gdal_1a897a57203542cfb2fd55ad204ad8d1/setup.py", line 88
#         except OSError, e:
#                       ^
#     SyntaxError: invalid syntax
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/29/03/e9a666aeeebcfcfa0c07b56c440a4e9fc45161cbf41fc23099427458f11c/GDAL-1.8.1.tar.gz#sha256=50640311ba0de4eb95d7b7dba22217384ff73f8cfabae32172027c7f785fc55e (from https://pypi.org/simple/gdal/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading GDAL-1.7.1.tar.gz (359 kB)
#      |████████████████████████████████| 359 kB 3.3 MB/s
# Requirement already satisfied: shapely>=1.0.14 in /home/alex/.local/lib/python3.8/site-packages (from -r https://raw.github.com/kartograph/kartograph.py/master/requirements.txt (line 2)) (1.7.1)
# Collecting pyshp
#   Downloading pyshp-2.1.3.tar.gz (219 kB)
#      |████████████████████████████████| 219 kB 2.1 MB/s
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from -r https://raw.github.com/kartograph/kartograph.py/master/requirements.txt (line 4)) (5.3.1)
# Collecting pykml
#   Downloading pykml-0.2.0-py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 379 kB/s
# Requirement already satisfied: pyproj in /home/alex/.local/lib/python3.8/site-packages (from -r https://raw.github.com/kartograph/kartograph.py/master/requirements.txt (line 6)) (3.0.0.post1)
# Collecting lxml
#   Downloading lxml-4.6.2-cp38-cp38-manylinux1_x86_64.whl (5.4 MB)
#      |████████████████████████████████| 5.4 MB 2.1 MB/s
# Collecting ordereddict
#   Downloading ordereddict-1.1.tar.gz (2.1 kB)
# Collecting tinycss
#   Downloading tinycss-0.4.tar.gz (87 kB)
#      |████████████████████████████████| 87 kB 2.2 MB/s
# Collecting argparse
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi in /home/alex/.local/lib/python3.8/site-packages (from pyproj->-r https://raw.github.com/kartograph/kartograph.py/master/requirements.txt (line 6)) (2020.6.20)
# Building wheels for collected packages: kartograph.py, GDAL, ordereddict, pyshp, tinycss
#   Building wheel for kartograph.py (setup.py) ... done
#   Created wheel for kartograph.py: filename=kartograph.py-0.6.8-py3-none-any.whl size=80866 sha256=eea605c626e1dd1329a64b443b42ec6f67080c32475f2ff4cf7025e5af2f16c5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-smim304p/wheels/a3/27/b7/4a833a432830ec4df88f28cea7f72f0443338c4343a873147d
#   Building wheel for GDAL (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-xw3wmjeh/gdal_dc9b4cce29674e97a0be46dd991732f1/setup.py'"'"'; __file__='"'"'/tmp/pip-install-xw3wmjeh/gdal_dc9b4cce29674e97a0be46dd991732f1/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-rp6n5ye_
#        cwd: /tmp/pip-install-xw3wmjeh/gdal_dc9b4cce29674e97a0be46dd991732f1/
#   Complete output (29 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.8
#   copying gdal.py -> build/lib.linux-x86_64-3.8
#   copying ogr.py -> build/lib.linux-x86_64-3.8
#   copying osr.py -> build/lib.linux-x86_64-3.8
#   copying gdalconst.py -> build/lib.linux-x86_64-3.8
#   copying gdalnumeric.py -> build/lib.linux-x86_64-3.8
#   creating build/lib.linux-x86_64-3.8/osgeo
#   copying osgeo/gdal.py -> build/lib.linux-x86_64-3.8/osgeo
#   copying osgeo/ogr.py -> build/lib.linux-x86_64-3.8/osgeo
#   copying osgeo/gdal_array.py -> build/lib.linux-x86_64-3.8/osgeo
#   copying osgeo/gdalconst.py -> build/lib.linux-x86_64-3.8/osgeo
#   copying osgeo/__init__.py -> build/lib.linux-x86_64-3.8/osgeo
#   copying osgeo/osr.py -> build/lib.linux-x86_64-3.8/osgeo
#   copying osgeo/gdalnumeric.py -> build/lib.linux-x86_64-3.8/osgeo
#   running build_ext
#   Could not run gdal-config!!!!
#   building 'osgeo._gdal' extension
#   creating build/temp.linux-x86_64-3.8
#   creating build/temp.linux-x86_64-3.8/extensions
#   x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I../../port -I../../gcore -I../../alg -I../../ogr/ -I/usr/include/python3.8 -I/home/alex/.local/lib/python3.8/site-packages/numpy/core/include -c extensions/gdal_wrap.cpp -o build/temp.linux-x86_64-3.8/extensions/gdal_wrap.o
#   extensions/gdal_wrap.cpp:2813:10: fatal error: cpl_port.h: No such file or directory
#    2813 | #include "cpl_port.h"
#         |          ^~~~~~~~~~~~
#   compilation terminated.
#   error: command 'x86_64-linux-gnu-gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for GDAL
#   Running setup.py clean for GDAL
#   Building wheel for ordereddict (setup.py) ... done
#   Created wheel for ordereddict: filename=ordereddict-1.1-py3-none-any.whl size=3553 sha256=cae52f34792eda2c9e8645edff9afa70649c5a68e19a415ec51186a472e5a693
#   Stored in directory: /home/alex/.cache/pip/wheels/57/8e/1c/402cdd15c1f9f7ec20fc63b7bb681cb50f7b09189486619f13
#   Building wheel for pyshp (setup.py) ... done
#   Created wheel for pyshp: filename=pyshp-2.1.3-py3-none-any.whl size=37264 sha256=608dc11dd1c22944400351a91d7ad056dfdb3a0c7f2671aef304db3ab3a754a9
#   Stored in directory: /home/alex/.cache/pip/wheels/1f/1b/b5/54affbefc8a7e2bdf1da000fc576b8a1c91338f1f327a04f4c
#   Building wheel for tinycss (setup.py) ... done
#   Created wheel for tinycss: filename=tinycss-0.4-py3-none-any.whl size=43941 sha256=2a510cd71063bdf506fbf7af85c93d3f1e9b1e4a4c0fb7326bb00c7e9efb3ed3
#   Stored in directory: /home/alex/.cache/pip/wheels/9a/9e/46/42a1ce4dca43c6b8e0c7ac03eb210872a90fce30f1bd82fa3b
# Successfully built kartograph.py ordereddict pyshp tinycss
# Failed to build GDAL
# Installing collected packages: lxml, tinycss, pyshp, pykml, ordereddict, kartograph.py, GDAL, argparse
#     Running setup.py install for GDAL ... error
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-xw3wmjeh/gdal_dc9b4cce29674e97a0be46dd991732f1/setup.py'"'"'; __file__='"'"'/tmp/pip-install-xw3wmjeh/gdal_dc9b4cce29674e97a0be46dd991732f1/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-_tbyr5hw/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /home/alex/.local/include/python3.8/GDAL
#          cwd: /tmp/pip-install-xw3wmjeh/gdal_dc9b4cce29674e97a0be46dd991732f1/
#     Complete output (29 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.8
#     copying gdal.py -> build/lib.linux-x86_64-3.8
#     copying ogr.py -> build/lib.linux-x86_64-3.8
#     copying osr.py -> build/lib.linux-x86_64-3.8
#     copying gdalconst.py -> build/lib.linux-x86_64-3.8
#     copying gdalnumeric.py -> build/lib.linux-x86_64-3.8
#     creating build/lib.linux-x86_64-3.8/osgeo
#     copying osgeo/gdal.py -> build/lib.linux-x86_64-3.8/osgeo
#     copying osgeo/ogr.py -> build/lib.linux-x86_64-3.8/osgeo
#     copying osgeo/gdal_array.py -> build/lib.linux-x86_64-3.8/osgeo
#     copying osgeo/gdalconst.py -> build/lib.linux-x86_64-3.8/osgeo
#     copying osgeo/__init__.py -> build/lib.linux-x86_64-3.8/osgeo
#     copying osgeo/osr.py -> build/lib.linux-x86_64-3.8/osgeo
#     copying osgeo/gdalnumeric.py -> build/lib.linux-x86_64-3.8/osgeo
#     running build_ext
#     Could not run gdal-config!!!!
#     building 'osgeo._gdal' extension
#     creating build/temp.linux-x86_64-3.8
#     creating build/temp.linux-x86_64-3.8/extensions
#     x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I../../port -I../../gcore -I../../alg -I../../ogr/ -I/usr/include/python3.8 -I/home/alex/.local/lib/python3.8/site-packages/numpy/core/include -c extensions/gdal_wrap.cpp -o build/temp.linux-x86_64-3.8/extensions/gdal_wrap.o
#     extensions/gdal_wrap.cpp:2813:10: fatal error: cpl_port.h: No such file or directory
#      2813 | #include "cpl_port.h"
#           |          ^~~~~~~~~~~~
#     compilation terminated.
#     error: command 'x86_64-linux-gnu-gcc' failed with exit status 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-xw3wmjeh/gdal_dc9b4cce29674e97a0be46dd991732f1/setup.py'"'"'; __file__='"'"'/tmp/pip-install-xw3wmjeh/gdal_dc9b4cce29674e97a0be46dd991732f1/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-_tbyr5hw/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /home/alex/.local/include/python3.8/GDAL Check the logs for full command output.
# Note: you may need to restart the kernel to use updated packages.
